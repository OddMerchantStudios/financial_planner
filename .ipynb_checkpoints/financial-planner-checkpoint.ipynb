# %% [markdown]
# # Unit 5 - Financial Planning

# %%
# Initial imports
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation

# %matplotlib inline

# %%
# Load .env enviroment variables
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Part 1 - Personal Finance Planner

# %% [markdown]
# ### Collect Crypto Prices Using the `requests` Library

# %%
# global variables
yesterday_date = (pd.Timestamp.today().date() - pd.Timedelta(days=1)).isoformat()
five_years_date = (pd.Timestamp.today().date() - pd.Timedelta(weeks = 52*5)).isoformat()

# %%
# Set current amount of crypto assets
my_btc = 1.2
my_eth = 5.3

# %%
# Crypto API URLs
btc_url = "https://api.alternative.me/v2/ticker/Bitcoin/?convert=USD"
eth_url = "https://api.alternative.me/v2/ticker/Ethereum/?convert=USD"

# %%
# Fetch current BTC price
btc_price = requests.get(btc_url).json()['data']['1']['quotes']['USD']['price']
# Fetch current ETH price
eth_price = requests.get(eth_url).json()['data']['1027']['quotes']['USD']['price']
# Compute current value of my crpto
my_btc_value = my_btc * btc_price
my_eth_value = my_eth * eth_price

# Print current crypto wallet balance
print(f"The current value of your {my_btc} BTC is ${round(my_btc_value,2)}")
print(f"The current value of your {my_eth} ETH is ${round(my_eth_value,2)}")
# Out:
# The current value of your 1.2 BTC is $33854.4
# The current value of your 5.3 ETH is $10274.31

# %% [markdown]
# ### Collect Investments Data Using Alpaca: `SPY` (stocks) and `AGG` (bonds)

# %%
# Set current amount of shares
my_agg = 200
my_spy = 50

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv('ALPACA_API_KEY')
alpaca_secret_key = os.getenv('ALPACA_SECRET_KEY')
print(type(alpaca_api_key))
# Create the Alpaca API object
alpaca = tradeapi.REST(alpaca_api_key, alpaca_secret_key, api_version='v2')
# Out:
# <class 'str'>

# %%
# Format current date as ISO format
today = pd.Timestamp(yesterday_date, tz = 'America/New_York')
# Set the tickers
tickers = ["AGG", "SPY"]

# Set timeframe to "1Day" for Alpaca API
timeframe = "1Day"

# Get current closing prices for SPY and AGG
portfolio_df = alpaca.get_bars(tickers,timeframe,yesterday_date,yesterday_date).df

# Reorganize the DataFrame
# Separate ticker data
AGG = portfolio_df[portfolio_df['symbol'] == 'AGG'].drop('symbol',axis =1)
SPY = portfolio_df[portfolio_df['symbol'] == 'SPY'].drop('symbol',axis =1)

# Concatenate the ticker DataFrames
portfolio_df = pd.concat([AGG, SPY], axis = 1, keys = ['AGG', 'SPY'])

# Preview DataFrame
portfolio_df
# Out:
#                              AGG                                            \
#                             open   high    low  close   volume trade_count
# timestamp
# 2023-04-19 04:00:00+00:00  98.89  98.93  98.71  98.89  3497459       18515
#
#                                          SPY                          \
#                                 vwap    open    high     low   close
# timestamp
# 2023-04-19 04:00:00+00:00  98.842722  412.22  415.08  412.16  414.14
#
#
#                              volume trade_count        vwap
# timestamp
# 2023-04-19 04:00:00+00:00  53692789      407857  413.666676

# %%
# Pick AGG and SPY close prices
agg_close_price = AGG['close'][-1]
spy_close_price = SPY['close'][-1]
# Print AGG and SPY close prices
print(f"Current AGG closing price: ${agg_close_price}")
print(f"Current SPY closing price: ${spy_close_price}")
# Out:
# Current AGG closing price: $98.89
# Current SPY closing price: $414.14

# %%
# Compute the current value of shares
my_spy_value = spy_close_price * my_spy
my_agg_value = agg_close_price * my_agg
# Print current value of shares
print(f"The current value of your {my_spy} SPY shares is ${my_spy_value:0.2f}")
print(f"The current value of your {my_agg} AGG shares is ${my_agg_value:0.2f}")
# Out:
# The current value of your 50 SPY shares is $20707.00
# The current value of your 200 AGG shares is $19778.00

# %% [markdown]
# ### Savings Health Analysis

# %%
# Set monthly household income
monthly_income = 12000

# Consolidate financial assets data
shares = my_spy_value + my_agg_value
crypto = my_btc_value + my_eth_value

# Create savings DataFrame
df_savings = pd.DataFrame([crypto, shares],index = ['crypto', 'shares'], columns = ['amount'])

# Display savings DataFrame
display(df_savings)
# Out:
#            amount
# crypto  44128.715
# shares  40485.000

# %%
# Plot savings pie chart
df_savings.plot.pie(y = 'amount')
# Out:
# <AxesSubplot:ylabel='amount'>

# %%
# Set ideal emergency fund
emergency_fund = monthly_income * 3

# Calculate total amount of savings
savings = df_savings['amount'].sum()

# Validate saving health
if savings >= emergency_fund:
    print('Congratulations! You have enough money in your emergency fund.')
else:
    print('You don\'t have enough money in your emergency fund.')
# Out:
# Congratulations! You have enough money in your emergency fund.

# %% [markdown]
# ## Part 2 - Retirement Planning
#
# ### Monte Carlo Simulation

# %%
# Set start and end dates of five years back from today.
# Sample results may vary from the solution based on the time frame chosen
start_date = five_years_date
end_date = yesterday_date

# %%
# Get 5 years' worth of historical data for SPY and AGG
df_stock_data = alpaca.get_bars(tickers, timeframe, start_date, end_date).df

# Reorganize the DataFrame
# Separate ticker data
AGG = df_stock_data[df_stock_data['symbol'] == 'AGG'].drop(['symbol','trade_count','vwap'],axis =1)
SPY = df_stock_data[df_stock_data['symbol'] == 'SPY'].drop(['symbol','trade_count','vwap'],axis =1)


# Concatenate the ticker DataFrames
df_stock_data = pd.concat([AGG, SPY], axis = 1, keys = ['AGG', 'SPY'])

# Display sample data
df_stock_data.head()
# Out:
#                               AGG                                      SPY  \
#                              open    high     low   close   volume    open
# timestamp
# 2018-04-26 04:00:00+00:00  105.83  105.90  105.76  105.85  4870388  264.79
# 2018-04-27 04:00:00+00:00  105.96  106.04  105.94  105.98  3806396  267.00
# 2018-04-30 04:00:00+00:00  106.01  106.12  105.99  106.00  4734506  267.26
# 2018-05-01 04:00:00+00:00  105.73  105.79  105.60  105.67  3027047  263.87
# 2018-05-02 04:00:00+00:00  105.70  105.78  105.62  105.67  2560754  264.76
#
#
#                                high     low   close    volume
# timestamp
# 2018-04-26 04:00:00+00:00  267.2452  264.29  266.24  67996934
# 2018-04-27 04:00:00+00:00  267.3400  265.50  266.58  57229880
# 2018-04-30 04:00:00+00:00  267.8900  264.43  264.53  82693981
# 2018-05-01 04:00:00+00:00  265.1000  262.11  264.96  76110600
# 2018-05-02 04:00:00+00:00  265.6800  262.76  263.17  86373743

# %%
# Configuring a Monte Carlo simulation to forecast 30 years cumulative returns
MC_stock_port = MCSimulation(
                df_stock_data,
                weights = [0.4, 0.6],
                num_simulation= 500,
                num_trading_days= 252*30
)

# %%
# Printing the simulation input data
MC_stock_port.portfolio_data.head()
# Out:
#                               AGG                                   \
#                              open    high     low   close   volume
# timestamp
# 2018-04-26 04:00:00+00:00  105.83  105.90  105.76  105.85  4870388
# 2018-04-27 04:00:00+00:00  105.96  106.04  105.94  105.98  3806396
# 2018-04-30 04:00:00+00:00  106.01  106.12  105.99  106.00  4734506
# 2018-05-01 04:00:00+00:00  105.73  105.79  105.60  105.67  3027047
# 2018-05-02 04:00:00+00:00  105.70  105.78  105.62  105.67  2560754
#
#                                            SPY                            \
#                           daily_return    open      high     low   close
# timestamp
# 2018-04-26 04:00:00+00:00          NaN  264.79  267.2452  264.29  266.24
# 2018-04-27 04:00:00+00:00     0.001228  267.00  267.3400  265.50  266.58
# 2018-04-30 04:00:00+00:00     0.000189  267.26  267.8900  264.43  264.53
# 2018-05-01 04:00:00+00:00    -0.003113  263.87  265.1000  262.11  264.96
# ...

# %%
# Running a Monte Carlo simulation to forecast 30 years cumulative returns
MC_stock_port.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# C:\Users\Horizon\Desktop\Gits\financial_planner\MCForecastTools.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   portfolio_cumulative_returns[n] = (1 + sim_df.fillna(0)).cumprod()
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# ...

# %%
# Plot simulation outcomes
line_plot = MC_stock_port.plot_simulation()

# %%
# Plot probability distribution and confidence intervals
dist_plot = MC_stock_port.plot_distribution()

# %% [markdown]
# ### Retirement Analysis

# %%
# Fetch summary statistics from the Monte Carlo simulation results
stat_table = MC_stock_port.summarize_cumulative_return()

# Print summary statistics
print(stat_table)
# Out:
# count           500.000000
# mean              6.832347
# std               5.279850
# min               0.336753
# 25%               3.397358
# 50%               5.379504
# 75%               8.596963
# max              38.650269
# 95% CI Lower      1.185209
# 95% CI Upper     21.398077
# Name: 7560, dtype: float64

# %% [markdown]
# ### Calculate the expected portfolio return at the `95%` lower and upper confidence intervals based on a `$20,000` initial investment.

# %%
# Set initial investment
initial_investment = 20000

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $20,000
ci_lower = round(stat_table[8]*initial_investment,2)
ci_upper = round(stat_table[9]*initial_investment,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 30 years will end within in the range of"
      f" ${ci_lower} and ${ci_upper}")
# Out:
# There is a 95% chance that an initial investment of $20000 in the portfolio over the next 30 years will end within in the range of $23704.18 and $427961.54

# %% [markdown]
# ### Calculate the expected portfolio return at the `95%` lower and upper confidence intervals based on a `50%` increase in the initial investment.

# %%
# Set initial investment
initial_investment = 20000 * 1.5

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $30,000
ci_lower = round(stat_table[8]*initial_investment,2)
ci_upper = round(stat_table[9]*initial_investment,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 30 years will end within in the range of"
      f" ${ci_lower} and ${ci_upper}")
# Out:
# There is a 95% chance that an initial investment of $30000.0 in the portfolio over the next 30 years will end within in the range of $35556.28 and $641942.31

# %% [markdown]
# ## Optional Challenge - Early Retirement
#
#
# ### Five Years Retirement Option

# %%
# Configuring a Monte Carlo simulation to forecast 5 years cumulative returns
MC_stock_port_5 = MCSimulation(
                df_stock_data,
                weights = [0.4, 0.6],
                num_simulation= 500,
                num_trading_days= 252*5
)

# %%
# Running a Monte Carlo simulation to forecast 5 years cumulative returns
MC_stock_port_5.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# C:\Users\Horizon\Desktop\Gits\financial_planner\MCForecastTools.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   portfolio_cumulative_returns[n] = (1 + sim_df.fillna(0)).cumprod()
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# ...

# %%
# Plot simulation outcomes
line_plot_5 = MC_stock_port_5.plot_simulation()

# %%
# Plot probability distribution and confidence intervals
dist_plot_5 = MC_stock_port_5.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
stat_table_5 = MC_stock_port_5.summarize_cumulative_return()

# Print summary statistics
print(stat_table_5)
# Out:
# count           500.000000
# mean              1.354002
# std               0.394351
# min               0.339770
# 25%               1.073925
# 50%               1.273614
# 75%               1.572563
# max               3.045193
# 95% CI Lower      0.782106
# 95% CI Upper      2.289146
# Name: 1260, dtype: float64

# %%
# Set initial investment
initial_investment = 60000

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $60,000
ci_lower_five = round(stat_table_5[8]*initial_investment,2)
ci_upper_five = round(stat_table_5[9]*initial_investment,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 5 years will end within in the range of"
      f" ${ci_lower_five} and ${ci_upper_five}")
# Out:
# There is a 95% chance that an initial investment of $60000 in the portfolio over the next 5 years will end within in the range of $46926.35 and $137348.77

# %% [markdown]
# ### Ten Years Retirement Option

# %%
# Configuring a Monte Carlo simulation to forecast 10 years cumulative returns
MC_stock_port_10 = MCSimulation(
                df_stock_data,
                weights = [0.4, 0.6],
                num_simulation= 500,
                num_trading_days= 252*10
)

# %%
# Running a Monte Carlo simulation to forecast 10 years cumulative returns
MC_stock_port_10.calc_cumulative_return()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# C:\Users\Horizon\Desktop\Gits\financial_planner\MCForecastTools.py:117: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   portfolio_cumulative_returns[n] = (1 + sim_df.fillna(0)).cumprod()
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# ...

# %%
# Plot simulation outcomes
line_plot_10 = MC_stock_port_10.plot_simulation()

# %%
# Plot probability distribution and confidence intervals
line_plot_10 = MC_stock_port_10.plot_distribution()

# %%
# Fetch summary statistics from the Monte Carlo simulation results
stat_table_10 = MC_stock_port_10.summarize_cumulative_return()

# Print summary statistics
print(stat_table_10)
# Out:
# count           500.000000
# mean              1.828460
# std               0.774062
# min               0.362277
# 25%               1.276153
# 50%               1.684616
# 75%               2.271376
# max               5.925445
# 95% CI Lower      0.764735
# 95% CI Upper      3.641515
# Name: 2520, dtype: float64

# %%
# Set initial investment
initial_investment = 60000

# Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes of our $60,000
ci_lower_ten = round(stat_table_10[8]*initial_investment,2)
ci_upper_ten = round(stat_table_10[9]*initial_investment,2)

# Print results
print(f"There is a 95% chance that an initial investment of ${initial_investment} in the portfolio"
      f" over the next 10 years will end within in the range of"
      f" ${ci_lower_ten} and ${ci_upper_ten}")
# Out:
# There is a 95% chance that an initial investment of $60000 in the portfolio over the next 10 years will end within in the range of $45884.11 and $218490.88
